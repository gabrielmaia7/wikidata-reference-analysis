# %%
a1_1 = [{
    "question": "Jag ___ inte om jordgubbar.",
    "options": [
        "tycker",
        "gillar",
        "tänker",
        "vill"
    ],
    "answer": 1
},
{
    "question": "Jag ___ till Kiruna i måndags.",
    "options": [
        "var",
        "åkte",
        "åker",
        "har varit"
    ],
    "answer": 2
},
{
    "question": "Det är ett ___ kafé.",
    "options": [
        "fin",
        "fina",
        "fint",
        "finn"
    ],
    "answer": 3
},
{
    "question": "Jag kan inte komma till festen imorgon. Vad ___!",
    "options": [
        "spännande",
        "snyggt",
        "synd",
        "slut"
    ],
    "answer": 3
},
{
    "question": "Jag har redan ___ den här boken.",
    "options": [
        "läste",
        "köp",
        "läst",
        "läs"
    ],
    "answer": 3
},
{
    "question": "Min väninna har ljust hår och ___ ögon.",
    "options": [
        "grön",
        "blå",
        "ljust",
        "blåa"
    ],
    "answer": 4
},
{
    "question": "Elin ___ en mycket stor villa för två år sedan.",
    "options": [
        "köpte",
        "har köpt",
        "ville köper",
        "ville köpte"
    ],
    "answer": 1
},
{
    "question": "Barnet hade mycket kläder på sig ___ det var ganska kallt ute.",
    "options": [
        "innan",
        "eftersom",
        "därför",
        "sedan"
    ],
    "answer": 2
},
{
    "question": "Jag ___ på Kafé Bullen för en vecka sedan.",
    "options": [
        "fixade",
        "fikade",
        "kulade ",
        "kände"
    ],
    "answer": 2
},
{
    "question": "Jag såg honom igår ___ klädaffären.",
    "options": [
        "på",
        "till",
        "mellan",
        "i"
    ],
    "answer": 4
}]

# %%
2000 % 1000
# Out:
# 0

# %%
a1_2 = [{
    "question": "Jag ___ inte om jordgubbar.",
    "options": [
        "tycker",
        "gillar",
        "tänker",
        "vill"
    ],
    "answer": 1
},
{
    "question": "Jag ___ till Kiruna i måndags.",
    "options": [
        "var",
        "åkte",
        "åker",
        "har varit"
    ],
    "answer": 2
},
{
    "question": "Det är ett ___ kafé.",
    "options": [
        "fin",
        "fina",
        "fint",
        "finn"
    ],
    "answer": 3
},
{
    "question": "Jag kan inte komma till festen imorgon. Vad ___!",
    "options": [
        "spännande",
        "snyggt",
        "synd",
        "slut"
    ],
    "answer": 3
},
{
    "question": "Jag har redan ___ den här boken.",
    "options": [
        "läste",
        "köp",
        "läst",
        "läs"
    ],
    "answer": 3
},
{
    "question": "Min väninna har ljust hår och ___ ögon.",
    "options": [
        "grön",
        "blå",
        "ljust",
        "blåa"
    ],
    "answer": 4
},
{
    "question": "Elin ___ en mycket stor villa för två år sedan.",
    "options": [
        "köpte",
        "har köpt",
        "ville köper",
        "ville köpte"
    ],
    "answer": 1
},
{
    "question": "Barnet hade mycket kläder på sig ___ det var ganska kallt ute.",
    "options": [
        "innan",
        "eftersom",
        "därför",
        "sedan"
    ],
    "answer": 2
},
{
    "question": "Jag ___ på Kafé Bullen för en vecka sedan.",
    "options": [
        "fixade",
        "fikade",
        "kulade ",
        "kände"
    ],
    "answer": 2
},
{
    "question": "Jag såg honom igår ___ klädaffären.",
    "options": [
        "på",
        "till",
        "mellan",
        "i"
    ],
    "answer": 4
}]

# %%
a2_1 = [{
    "question": "Vad heter ___ ?",
    "options": [
        "din",
        "mig",
        "du",
        "honom"
    ],
    "answer": 3
},
{
    "question": "Hon ___ på teve.",
    "options": [
        "titta",
        "tittar",
        "titter",
        "tycker"
    ],
    "answer": 2
},
{
    "question": "Klockan är kvart ___ nio.",
    "options": [
        "över",
        "till",
        "mot",
        "på"
    ],
    "answer": 1
},
{
    "question": "Jag är gift. Min ___ heter Anders.",
    "options": [
        "sambo",
        "pojkvän",
        "kompis",
        "man"
    ],
    "answer": 4
},
{
    "question": "Jag ska ___ till Stockholm på måndag.",
    "options": [
        "åkte",
        "åkar",
        "åka",
        "åker"
    ],
    "answer": 3
},
{
    "question": "Jag skulle ___ ha en kopp kaffe, tack.",
    "options": [
        "vill",
        "vilja",
        "veta",
        "ville"
    ],
    "answer": 2
},
{
    "question": "Det finns två ___ i vardagsrummet.",
    "options": [
        "lamper",
        "lampor",
        "lampa",
        "lampar"
    ],
    "answer": 2
},
{
    "question": "Är hon gift med honom? Ja, ___",
    "options": [
        "det har hon",
        "det är hon",
        "hon är inte",
        "det hon är"
    ],
    "answer": 2
},
{
    "question": "Thomas, vänta på mig! Jag måste prata med ___",
    "options": [
        "honom",
        "han",
        "du",
        "dig"
    ],
    "answer": 4
},
{
    "question": "Här ___ man inte röka!",
    "options": [
        "måste",
        "får",
        "har",
        "är"
    ],
    "answer": 2
}
]

# %%
a2_2 = [{
    "question": "Vad heter ___ ?",
    "options": [
        "din",
        "mig",
        "du",
        "honom"
    ],
    "answer": 3
},
{
    "question": "Hon ___ på teve.",
    "options": [
        "titta",
        "tittar",
        "titter",
        "tycker"
    ],
    "answer": 2
},
{
    "question": "Klockan är kvart ___ nio.",
    "options": [
        "över",
        "till",
        "mot",
        "på"
    ],
    "answer": 1
},
{
    "question": "Jag är gift. Min ___ heter Anders.",
    "options": [
        "sambo",
        "pojkvän",
        "kompis",
        "man"
    ],
    "answer": 4
},
{
    "question": "Jag ska ___ till Stockholm på måndag.",
    "options": [
        "åkte",
        "åkar",
        "åka",
        "åker"
    ],
    "answer": 3
},
{
    "question": "Jag skulle ___ ha en kopp kaffe, tack.",
    "options": [
        "vill",
        "vilja",
        "veta",
        "ville"
    ],
    "answer": 2
},
{
    "question": "Det finns två ___ i vardagsrummet.",
    "options": [
        "lamper",
        "lampor",
        "lampa",
        "lampar"
    ],
    "answer": 2
},
{
    "question": "Är hon gift med honom? Ja, ___",
    "options": [
        "det har hon",
        "det är hon",
        "hon är inte",
        "det hon är"
    ],
    "answer": 2
},
{
    "question": "Thomas, vänta på mig! Jag måste prata med ___",
    "options": [
        "honom",
        "han",
        "du",
        "dig"
    ],
    "answer": 4
},
{
    "question": "Här ___ man inte röka!",
    "options": [
        "måste",
        "får",
        "har",
        "är"
    ],
    "answer": 2
}]

# %%
a2_3 = [{
        "question": "Vad heter ___ ?",
        "options": [
            "din",
            "mig",
            "du",
            "honom"
        ],
        "answer": 3
    },
    {
        "question": "Hon ___ på teve.",
        "options": [
            "titta",
            "tittar",
            "titter",
            "tycker"
        ],
        "answer": 2
    },
    {
        "question": "Klockan är kvart ___ nio.",
        "options": [
            "över",
            "till",
            "mot",
            "på"
        ],
        "answer": 1
    },
    {
        "question": "Jag är gift. Min ___ heter Anders.",
        "options": [
            "sambo",
            "pojkvän",
            "kompis",
            "man"
        ],
        "answer": 4
    },
    {
        "question": "Jag ska ___ till Stockholm på måndag.",
        "options": [
            "åkte",
            "åkar",
            "åka",
            "åker"
        ],
        "answer": 3
    },
    {
        "question": "Jag skulle ___ ha en kopp kaffe, tack.",
        "options": [
            "vill",
            "vilja",
            "veta",
            "ville"
        ],
        "answer": 2
    },
    {
        "question": "Det finns två ___ i vardagsrummet.",
        "options": [
            "lamper",
            "lampor",
            "lampa",
            "lampar"
        ],
        "answer": 2
    },
    {
        "question": "Är hon gift med honom? Ja, ___",
        "options": [
            "det har hon",
            "det är hon",
            "hon är inte",
            "det hon är"
        ],
        "answer": 2
    },
    {
        "question": "Thomas, vänta på mig! Jag måste prata med ___",
        "options": [
            "honom",
            "han",
            "du",
            "dig"
        ],
        "answer": 4
    },
    {
        "question": "Här ___ man inte röka!",
        "options": [
            "måste",
            "får",
            "har",
            "är"
        ],
        "answer": 2
    }]

# %%
a3_1 = [{
"question": "Ska du vara ___ ikväll?",
"options": [
"hem",
"hus",
"hemma",
"ut"
],
"answer": 3
},
{
"question": "Svenskar ___ midsommar i slutet av juni.",
"options": [
"fyller",
"firar",
"ha ",
"lägger"
],
"answer": 2
},
{
"question": "Min bror är ___ än jag.",
"options": [
"långare",
"längre",
"äldst",
"längst"
],
"answer": 2
},
{
"question": "Vad heter den ___ sjön i Sverige?",
"options": [
"största",
"stor",
"större ",
"störst"
],
"answer": 1
},
{
"question": "Mattias funderar på att ___ en ny bil.",
"options": [
"svika",
"snacka",
"syssla",
"skaffa"
],
"answer": 4
},
{
"question": "Vi var i Norge ___ .",
"options": [
"i jul",
"i julas",
"på jul",
"på julen"
],
"answer": 2
},
{
"question": "Jag brukar träna två gånger ___ veckan.",
"options": [
"om",
"varje",
"i",
"på"
],
"answer": 2
},
{
"question": "Hon är ___ i honom.",
"options": [
"trogen",
"kär ",
"intresserad",
"arg"
],
"answer": 3
},
{
"question": "Om man bor i en lägenhet, måste man ___ hänsyn till sina grannar.",
"options": [
"visa",
"vissa ",
"vissla ",
"viska"
],
"answer": 1
},
{
"question": "Porten ___ klockan tolv på natten.",
"options": [
"stänger",
"stängs",
"stängas ",
"stängt"
],
"answer": 1
}]

# %%
a3_2 = [{
"question": "Ska du vara ___ ikväll?",
"options": [
"hem",
"hus",
"hemma",
"ut"
],
"answer": 3
},
{
"question": "Svenskar ___ midsommar i slutet av juni.",
"options": [
"fyller",
"firar",
"ha ",
"lägger"
],
"answer": 2
},
{
"question": "Min bror är ___ än jag.",
"options": [
"långare",
"längre",
"äldst",
"längst"
],
"answer": 2
},
{
"question": "Vad heter den ___ sjön i Sverige?",
"options": [
"största",
"stor",
"större ",
"störst"
],
"answer": 1
},
{
"question": "Mattias funderar på att ___ en ny bil.",
"options": [
"svika",
"snacka",
"syssla",
"skaffa"
],
"answer": 4
},
{
"question": "Vi var i Norge ___ .",
"options": [
"i jul",
"i julas",
"på jul",
"på julen"
],
"answer": 2
},
{
"question": "Jag brukar träna två gånger ___ veckan.",
"options": [
"om",
"varje",
"i",
"på"
],
"answer": 3
},
{
"question": "Hon är ___ i honom.",
"options": [
"trogen",
"kär ",
"intresserad",
"arg"
],
"answer": 2
},
{
"question": "Om man bor i en lägenhet, måste man ___ hänsyn till sina grannar.",
"options": [
"visa",
"vissa ",
"vissla ",
"viska"
],
"answer": 1
},
{
"question": "Porten ___ klockan tolv på natten.",
"options": [
"stänger",
"stängs",
"stängas ",
"stängt"
],
"answer": 1
}
]

# %%
a3_3 = [{   "question": "Ska du vara ___ ikväll?",
    "options": [
        "hem",
        "hus",
        "hemma",
        "ut"
    ],
    "answer": 3
},
{
    "question": "Svenskar ___ midsommar i slutet av juni.",
    "options": [
        "fyller",
        "firar",
        "ha ",
        "lägger"
    ],
    "answer": 2
},
{
    "question": "Min bror är ___ än jag.",
    "options": [
        "långare",
        "längre",
        "äldst",
        "längst"
    ],
    "answer": 2
},
{
    "question": "Vad heter den ___ sjön i Sverige?",
    "options": [
        "största",
        "stor",
        "större    ",
        "störst"
    ],
    "answer": 1
},
{
    "question": "Mattias funderar på att ___ en ny bil.",
    "options": [
        "svika",
        "snacka",
        "syssla",
        "skaffa"
    ],
    "answer": 4
},
{
    "question": "Vi var i Norge ___ .",
    "options": [
        "i jul",
        "i julas",
        "på jul",
        "på julen"
    ],
    "answer": 2
},
{
    "question": "Jag brukar träna två gånger ___ veckan.",
    "options": [
        "om",
        "varje",
        "i",
        "på"
    ],
    "answer": 3
},
{
    "question": "Hon är ___ i honom.",
    "options": [
        "trogen",
        "kär  ",
        "intresserad",
        "arg"
    ],
    "answer": 2
},
{
    "question": "Om man bor i en lägenhet, måste man ___ hänsyn till sina grannar.",
    "options": [
        "visa",
        "vissa ",
        "vissla ",
        "viska"
    ],
    "answer": 1
},
{
    "question": "Porten ___ klockan tolv på natten.",
    "options": [
        "stänger",
        "stängs",
        "stängas ",
        "stängt"
    ],
    "answer": 1
}]

# %%
a4_1 = [{
"question": "Tjuvarna tog alla hennes gamla ___",
"options": [
"fotot",
"foton",
"fotona",
"foto"
],
"answer": 2
},
{
"question": "Jag ___ till jobbet.",
"options": [
"åker med tåg",
"åker på tåg",
"åker tåg",
"reser tåg"
],
"answer": 3
},
{
"question": "Kan jag hjälpa ___ med något?",
"options": [
"mot",
"till",
"för",
"du"
],
"answer": 2
},
{
"question": "Tjejen tyckte bäst om det ___ vinet.",
"options": [
"röd",
"rött",
"franska",
"franskt"
],
"answer": 3
},
{
"question": "Hon är trött på ___ jobb.",
"options": [
"hennes",
"hans",
"mitt",
"sitt"
],
"answer": 4
},
{
"question": "Jag ___ igår därför att det var mycket kallt i luften.",
"options": [
"fryser",
"frös",
"frusit",
"fnös"
],
"answer": 2
},
{
"question": "Emma ringde och sa att hon ___ komma hem snart.",
"options": [
"ska",
"skal",
"kanske",
"skulle"
],
"answer": 4
},
{
"question": "Jag har aldrig varit i Kina, men jag ___ att det är vackert där.",
"options": [
"tänker",
"tycker ",
"tror",
"hör"
],
"answer": 3
},
{
"question": "Det är ganska sent. Jag tror att vi inte ___ med tåget.",
"options": [
"hinner ",
"hittar",
"hyr",
"finns"
],
"answer": 1
},
{
"question": "Peter sålde sin bil ___ spara pengar.",
"options": [
"för att",
"men",
"till att ",
"därför att"
],
"answer": 1
}]

# %%
a4_2 = [{
"question": "Tjuvarna tog alla hennes gamla ___",
"options": [
"fotot",
"foton",
"fotona",
"foto"
],
"answer": 2
},
{
"question": "Jag ___ till jobbet.",
"options": [
"åker med tåg",
"åker på tåg",
"åker tåg",
"reser tåg"
],
"answer": 3
},
{
"question": "Kan jag hjälpa ___ med något?",
"options": [
"mot",
"till",
"för",
"du"
],
"answer": 2
},
{
"question": "Tjejen tyckte bäst om det ___ vinet.",
"options": [
"röd",
"rött",
"franska",
"franskt"
],
"answer": 3
},
{
"question": "Hon är trött på ___ jobb.",
"options": [
"hennes",
"hans",
"mitt",
"sitt"
],
"answer": 4
},
{
"question": "Jag ___ igår därför att det var mycket kallt i luften.",
"options": [
"fryser",
"frös",
"frusit",
"fnös"
],
"answer": 2
},
{
"question": "Emma ringde och sa att hon ___ komma hem snart.",
"options": [
"ska",
"skal",
"kanske",
"skulle"
],
"answer": 1
},
{
"question": "Jag har aldrig varit i Kina, men jag ___ att det är vackert där.",
"options": [
"tänker",
"tycker ",
"tror",
"hör"
],
"answer": 3
},
{
"question": "Det är ganska sent. Jag tror att vi inte ___ med tåget.",
"options": [
"hinner ",
"hittar",
"hyr",
"finns"
],
"answer": 1
},
{
"question": "Peter sålde sin bil ___ spara pengar.",
"options": [
"för att",
"men",
"till att ",
"därför att"
],
"answer": 1
}]

# %%
assert([a['answer'] for a in a1_1] == [a['answer'] for a in a1_2])
assert([a['answer'] for a in a2_1] == [a['answer'] for a in a2_2])
assert([a['answer'] for a in a2_1] == [a['answer'] for a in a2_3])
assert([a['answer'] for a in a3_2] == [a['answer'] for a in a3_3])
assert([a['answer'] for a in a4_1] == [a['answer'] for a in a4_1])

# %%
a = a2_1 + a1_1 + a4_1 + a3_1
for i in range(40):
    a[i]['answer'] -=1

# %%
import json

# %%
with open('Crowdsourcing/data/language_tests.json','rb') as f:
    a_l = json.load(f)
    
for i in range(40):
    try:
        assert(a_l['sv'][i]['answer'] == a[i]['answer'])
    except:
        print(a_l['sv'][i])
        print(a[i])
        raise

# %%
jap = [
        {
            "question":"___ namae wa nan desu ka?",
            "options":["anata wa","anata ga","anata no","anata o"],
            "answer":3
        },
        
        {
            "question":"Watashitachiwa igirisu jin desu. Watashitachi wa London ___kimashita",
            "options":["ga","nite","de","kara"],
            "answer":4
        },
        
        {
            "question":"Janesan wa ___ kirei desu",
            "options":["dokode","dakara","totemo","sukoshi"],
            "answer":3
        },
        
        {
            "question":"Chugokugo no jisho wa ___?",
            "options":["arimasen desu ka","imasu ka","arimasu ka","imasen desu ka"],
            "answer":3
        },
        
        {
            "question":"Korewa  Margaret san ___hon desu",
            "options":["nihongo","nihon no","no","ga"],
            "answer":3
        },
        
        {
            "question":"Tsukueno ue ni ___ arimasu ka?",
            "options":["dare ga","nani ga","donata de","nan de"],
            "answer":2
        },
        
        {
            "question":"Mo ichido___kudasai",
            "options":["ikite","itara","iitara","itte"],
            "answer":4
        },
        
        {
            "question":"Sumisusan wa ashita kaisha no hito ___ Osaka ni ikimasu.",
            "options":["ya","ga","ni","to"],
            "answer":4
        },
        
        {
            "question":"Kotoshino natsuyasumi wa doko___ikimasu ka?",
            "options":["ni","de","no","ga"],
            "answer":1
        },
        
        {
            "question":"Janesan no tanjobi wa___desu ka?",
            "options":["nan","doko","itsu","ari"],
            "answer":3
        },
        
        {
            "question":"Watashi wa basu___tomodachi no uchi ni ikimasu.",
            "options":["de","ga","no","ni"],
            "answer":1
        },
        
        {
            "question":"Anatawa ___ de shigoto ni ikimasu ka?",
            "options":["doko","nan","itsu","mada"],
            "answer":2
        },
        
        {
            "question":"Nichiyobini Kyoto de o-matsuri ___mimasu.",
            "options":["o","ni","ga","e"],
            "answer":1
        },
        
        {
            "question":"Tom san wa ___ eiga no kippu o agemashita ka?",
            "options":["dare ga","dare ni","donata kara","donata de"],
            "answer":2
        },
        
        {
            "question":"Kinono pati wa totemo___",
            "options":["nigiyaka desu","omoshiroi deshita","nigiyaka deshita","omoshiroi desu"],
            "answer":3
        },
        
        {
            "question":"Yakyū no shiai o 1-shūkan saki___nobashimashō.",
            "options":["ni","de","nara","kara"],
            "answer":1
        },
        
        {
            "question":"Anoresutoran wa amari shizuka ___",
            "options":["dewa arimasu","dewa arimasen","deshita","desu"],
            "answer":2
        },
        
        {
            "question":"Konban jikan ga ___?",
            "options":["ikimasu ka","imasu ka","irimasu ka","arimasu ka"],
            "answer":4
        },
        
        {
            "question":"Kelly san wa kino hon-ya ni ___ , hon o kaimashita.",
            "options":["itte","ikite","ikinagara","ikimashita"],
            "answer":1
        },
        
        {
            "question":"Futatsu mae no kado ___hidari ni magatte kudasai.",
            "options":["de","ga","ni","no"],
            "answer":1
        },
        
        {
            "question":"Soko wa chusha kinshi desu___, kuruma o tomenaide kudasai.",
            "options":["ga","kara","made","dakara"],
            "answer":2
        },
        
        {
            "question":"Sushi ni wasabi o ___kudasai",
            "options":["irenaide","motteikanaide","tabenaide","kawanaide"],
            "answer":1
        },
        
        {
            "question":"Tanaka san wa gorufu___jozu desu.",
            "options":["ni","o","ga","tte"],
            "answer":3
        },
        
        {
            "question":"Kesa kara  atama ___itai desu.",
            "options":["o","ga","made","no"],
            "answer":2
        },
        
        {
            "question":"Margaret-san wa ima nani o ___?",
            "options":["surun desu ka","suruno","shirimasu ka","shite imasu ka"],
            "answer":4
        },
        
        {
            "question":"Watashi wa maishu Nihongo o ___imasu.",
            "options":["naratte","itte","shite","naraite"],
            "answer":1
        },
        
        {
            "question":"Hikoki ga sora o ___",
            "options":["hashitte imasu","tonde imasu","hashirimasu","tobimashita"],
            "answer":2
        },
        
        {
            "question":"Jikan ga arimasenkara, ___houga iidesuyo.",
            "options":["isoide","isoida","isogu","isoganai"],
            "answer":2
        },
        
        {
            "question":"Kaigi wa mada ___to omoimasu",
            "options":["owanai","owari","owattenai","owatta"],
            "answer":3
        },
        
        {
            "question":"Suzuki san wa ototoshi daigaku o sotsugyo ___desu ka?",
            "options":["suru","shita","shitan","surun"],
            "answer":3
        },
        
        {
            "question":"Tegami o ___wasuremashita.",
            "options":["okuri o","dashite","dasuno o","okutte"],
            "answer":3
        },
        
        {
            "question":"Kino, ame ga ___ , haikingu wa yamemashita.",
            "options":["furukara","futtanode","fuite","furimasu kara"],
            "answer":2
        },
        
        {
            "question":"Hayakere ba___ii desu.",
            "options":["hayai   hodo","hayai node","hayai kara","hayai kute"],
            "answer":1
        },
        
        {
            "question":"Tabako o ___ omoimasu.",
            "options":["yamemasu","yamete to","yametai na","yameyō to"],
            "answer":4
        },
        
        {
            "question":"1-nen ni nan-nichi kaisha o ___ka?",
            "options":["yasumemasu","yasume","yasumete ","yasumude imasu"],
            "answer":1
        },
        
        {
            "question":"Anata wa Eigo no jisho ga ___ka?",
            "options":["yomemasu","yomimasu","hikemasu","hikimasu"],
            "answer":3
        },
        
        {
            "question":"Supōtsu no ___ tenisu ga ichiban suki desu.",
            "options":["naka wa","naka de","aida wa","aida de"],
            "answer":2
        },
        
        {
            "question":"London dewa chikatetsu ga ___yō desu.",
            "options":["benri da","benri ga yoi","banri ga ii","benri na"],
            "answer":4
        },
        
        {
            "question":"Denki o ___ , dekake te shimattan desu.",
            "options":["tsuke tara","tukewasure","keshiwasurete","keshite"],
            "answer":4
        },
        
        {
            "question":"Tesuto wa totemo muzukashikatta___, tochū de akirame___.",
            "options":["desu/mashita","kara/masu","node/mashita  ","mitaide/ta"],
            "answer":3
        }
    ]

for i in range(40):
    jap[i]['answer'] -=1

# %%
with open('Crowdsourcing/data/language_tests.json','rb') as f:
    a_l = json.load(f)
    
for i in range(40):
    try:
        assert(a_l['ja'][i]['answer'] == jap[i]['answer'])
    except:
        print(a_l['ja'][i])
        print(jap[i])
        raise

# %%
with open('Crowdsourcing/data/language_tests.json','rb') as f:
    a_l = json.load(f)
for x in a_l['pt']:
    print(x['question'].replace('___',x['options'][x['answer']]))
# Out:
# Qual é o seu nome?
# Nós somos Chineses de Beijing
# Jane é muito simpática e educada
# Você tem uma caneta?
# Onde é que vocês Vão se encontrar?
# Eles não estavam em casa na noite passada
# O que é que você disse?
# Porque é que você está a chorar?
# Onde é que vocês vão passar as próximas ferias de verão?
# Mais tarde, vamos nos encontrar todos no hotel.
# Os relógios Seiko são feitos no Japão
# Eu não/nenhum vejo não/nenhum taxi.
# A familia Soares foi convidada pelo senhor Martins e pela dona Carla.
# Nós vamos comprar uma revista para lermos durante a viagem.
# O sócio do senhor Soares já tinha saido quando ele chegou.
# Eu lamento/possamos que nós não lamento/possamos passar mais tempo juntos.
# Nós havemos de ir a Amazonia.
# Ultimamente tem havido muitos acidentes.
# Se nós não arranjarmos/iremos bilhetes para o concerto, arranjarmos/iremos ao teatro.
# Ele disse-me que voltaria/houvesse para Portugal se lá voltaria/houvesse emprego para ele.
# ...
